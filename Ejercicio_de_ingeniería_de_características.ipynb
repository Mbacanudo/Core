# %% [markdown]
# <a href="https://colab.research.google.com/github/Mbacanudo/Core/blob/main/Ejercicio_de_ingenier%C3%ADa_de_caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio de ingeniería de características (base)
# En este ejercicio trabajarás con los datos sobre el alquiler de bicicletas compartidas.
#
# La tarea es diseñar algunas nuevas características para intentar mejorar la capacidad de un modelo para predecir el número total del alquiler de bicicletas compartidas durante una hora determinada del día.

# %% [markdown]
# 1. Importa los datos y elimina las columnas “casual” y “registered”.  Aquellas son redundantes para tu objetivo, “count”.

# %%
import pandas as pd
import numpy as np

# %%
file = "/content/bikeshare_train - bikeshare_train.csv"
df = pd.read_csv(file)
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.drop(columns=["casual", "registered"], inplace=True)
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1

# %% [markdown]
# Transforma la columna de fecha y hora en un tipo de fecha hora y utilízalo para crear 3 columnas nuevas en el dataframe que contenga:
#
#   1. Nombre del mes
#   2. Nombre del día de la semana
#   3. Hora del día

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 850.6+ KB

# %%
df["datetime"] = pd.to_datetime(df["datetime"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6)
# memory usage: 850.6 KB

# %%
df["monthname"] = df["datetime"].dt.month_name()
df["dayname"] = df["datetime"].dt.day_name()
df["hour"] = df["datetime"].dt.time
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count monthname   dayname      hour
# 0        81        0.0     16   January  Saturday  00:00:00
# 1        80        0.0     40   January  Saturday  01:00:00
# 2        80        0.0     32   January  Saturday  02:00:00
# 3        75        0.0     13   January  Saturday  03:00:00
# 4        75        0.0      1   January  Saturday  04:00:00

# %% [markdown]
# Asegúrate que todas las 3 nuevas columnas son un tipo de datos “objeto” para que se más tarde se le aplica una codificación one-hot.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
#  10  monthname   10886 non-null  object
#  11  dayname     10886 non-null  object
#  12  hour        10886 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(6), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
#  Elimina las columnas “datetime” y “season”.  Estas son ahora redundantes.

# %%
df.drop(columns=["datetime", "season"], inplace=True)
df.head()
# Out:
#    holiday  workingday  weather  temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  9.84  14.395        81        0.0     16
# 1        0           0        1  9.02  13.635        80        0.0     40
# 2        0           0        1  9.02  13.635        80        0.0     32
# 3        0           0        1  9.84  14.395        75        0.0     13
# 4        0           0        1  9.84  14.395        75        0.0      1
#
#   monthname   dayname      hour
# 0   January  Saturday  00:00:00
# 1   January  Saturday  01:00:00
# 2   January  Saturday  02:00:00
# 3   January  Saturday  03:00:00
# 4   January  Saturday  04:00:00

# %% [markdown]
# Las temperaturas en la columna “temp” y “atemp” son en Celsius. Utiliza .appply() para convertirlas en Fahrenheit.
#
# formula de transformacion: ºF = (ºC · 1,8) + 32

# %%
def fahrenheit(columna):
    return columna * 1.8 + 32

df['temp'] = df['temp'].apply(fahrenheit)
df.head()
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  14.395        81        0.0     16
# 1        0           0        1  48.236  13.635        80        0.0     40
# 2        0           0        1  48.236  13.635        80        0.0     32
# 3        0           0        1  49.712  14.395        75        0.0     13
# 4        0           0        1  49.712  14.395        75        0.0      1
#
#   monthname   dayname      hour
# 0   January  Saturday  00:00:00
# 1   January  Saturday  01:00:00
# 2   January  Saturday  02:00:00
# 3   January  Saturday  03:00:00
# 4   January  Saturday  04:00:00

# %%
df['atemp'] = df['atemp'].apply(fahrenheit)
df.head()
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81        0.0     16
# 1        0           0        1  48.236  56.543        80        0.0     40
# 2        0           0        1  48.236  56.543        80        0.0     32
# 3        0           0        1  49.712  57.911        75        0.0     13
# 4        0           0        1  49.712  57.911        75        0.0      1
#
#   monthname   dayname      hour
# 0   January  Saturday  00:00:00
# 1   January  Saturday  01:00:00
# 2   January  Saturday  02:00:00
# 3   January  Saturday  03:00:00
# 4   January  Saturday  04:00:00

# %% [markdown]
# Crea una nueva columna, “temp_variance” que es la diferencia entre “temp” y “atemp”. Elimina la columna “atemp”.

# %%
df["temp_variance"] = df["temp"] - df["atemp"]
df.head()
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81        0.0     16
# 1        0           0        1  48.236  56.543        80        0.0     40
# 2        0           0        1  48.236  56.543        80        0.0     32
# 3        0           0        1  49.712  57.911        75        0.0     13
# 4        0           0        1  49.712  57.911        75        0.0      1
#
#   monthname   dayname      hour  temp_variance
# 0   January  Saturday  00:00:00         -8.199
# 1   January  Saturday  01:00:00         -8.307
# 2   January  Saturday  02:00:00         -8.307
# 3   January  Saturday  03:00:00         -8.199
# 4   January  Saturday  04:00:00         -8.199

# %%
df.drop(columns="atemp", inplace=True)
df.head()
# Out:
#    holiday  workingday  weather    temp  humidity  windspeed  count monthname  \
# 0        0           0        1  49.712        81        0.0     16   January
# 1        0           0        1  48.236        80        0.0     40   January
# 2        0           0        1  48.236        80        0.0     32   January
# 3        0           0        1  49.712        75        0.0     13   January
# 4        0           0        1  49.712        75        0.0      1   January
#
#     dayname      hour  temp_variance
# 0  Saturday  00:00:00         -8.199
# 1  Saturday  01:00:00         -8.307
# 2  Saturday  02:00:00         -8.307
# 3  Saturday  03:00:00         -8.199
# 4  Saturday  04:00:00         -8.199
